# %% [markdown]
# ##**IMPORTING REQUIRED LIBRARIES**

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ##**DATA LOADING WITH PANDAS: SIMPLIFYING EDA**

# %% [markdown]
# *Learn how to effortlessly load CSV data into a Pandas DataFrame, a pivotal step in Exploratory Data Analysis (EDA). With CSV files typically storing comma-separated values, Pandas offers a seamless solution for reading and parsing such data. This tutorial demonstrates how to harness the power of Pandas to quickly load your data, enabling efficient exploration and analysis.*

# %%
df_employee = pd.read_csv("C:\\Users\\USER\\OneDrive\\Desktop\\anju entri\\myexcel - myexcel.csv.csv")

# %%
df_employee
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ###**PRELIMINARY EXPLORATORY DATA ANALYSIS (EDA) FOR UNDERSTANDING DATASET STRUCTURE AND CONTENTS**

# %% [markdown]
# *head() will give the first 5 rows of the data*

# %%
df_employee.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# *tail() will give the last 5 rows of the data*

# %%
df_employee.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24  06-Jan     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     7-0     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25  07-Mar     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %% [markdown]
# *isnull() generates boolean values indicating the missing values*

# %%
df_employee.isnull()
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  Salary
# 0    False  False   False     False  False   False   False    False   False
# 1    False  False   False     False  False   False   False    False   False
# 2    False  False   False     False  False   False   False    False    True
# 3    False  False   False     False  False   False   False    False   False
# 4    False  False   False     False  False   False   False     True   False
# ..     ...    ...     ...       ...    ...     ...     ...      ...     ...
# 453  False  False   False     False  False   False   False    False   False
# 454  False  False   False     False  False   False   False     True   False
# 455  False  False   False     False  False   False   False     True   False
# 456  False  False   False     False  False   False   False    False   False
# 457  False  False   False     False  False   False   False    False   False
#
# [458 rows x 9 columns]

# %% [markdown]
# *snull().sum() it computes the sum of he boolean values and gives the total*

# %%
df_employee.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %% [markdown]
# ##**DATA CLEANING AND DATA ANALYSIS**

# %% [markdown]
# 1. Checking Data Types:
#
# *Understanding data types is essential to ensure accurate analysis.
# Ensuring numerical values are not mistakenly stored as strings is crucial for plotting data.*
#
# 2. Data Cleaning:
#
# *Process of removing unwanted variables and values from the dataset to address irregularities.
# Irregularities can skew data disproportionately and affect analysis outcomes adversely.*
#
# 3.General Knowledge About Data:
#
# *Understanding various aspects of the dataset, including values, types, number of rows and columns, and missing values, is crucial.
# Primary objective is to gain insights into the datasets structure and contents.*

# %%
df_employee.dtypes
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int64
# Height       object
# Weight        int64
# College      object
# Salary      float64
# dtype: object

# %% [markdown]
# 4.Utilizing describe():
#
# *Statistical summary provided by df.describe() includes count, mean, standard deviation, minimum, and quartiles for each numerical column.
# Summary helps in understanding the dataset's central tendencies and spread.*
#
# 5.Checking for Duplicates and Missing Values:
#
# *-Essential steps in data cleaning process.*
# *-Detecting duplicates and handling missing values ensures reliability and accuracy of analysis results.*
#
# 6.Understanding Dataset Shape:
#
# *-shape attribute indicates the number of features and observations in the dataset.*
# *-Provides insight into the dataset's dimensions.*
#
# 7.Using info():
#
# *-Facilitates comprehension of data types and related information, such as quantity of records in each column, presence of null values, and dataset memory usage.*
# *-Helps in understanding dataset characteristics and potential issues.*

# %%
df_employee.shape
# Out:
# (458, 9)

# %%
df_employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df_employee.describe()
# Out:
#            Number         Age      Weight        Salary
# count  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  221.543668  4.833970e+06
# std     15.966837    4.400128   26.343200  5.226620e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
# Increase figure size for better clarity
plt.figure(figsize=(8, 4))

# Create boxplot
sns.boxplot(x=df_employee["Height"])

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show plot
plt.show()

# %%
# Increase figure size for better clarity
plt.figure(figsize=(10,7))

# Create boxplot
sns.boxplot(x=df_employee["Team"])

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show plot
plt.show()

# %%
df_employee["Team"].nunique()#no of unique values in team
# Out:
# 30

# %%
df_employee["Position"].nunique()
# Out:
# 5

# %%
df_employee.columns.tolist()#convert column variable to python list
# Out:
# ['Name',
#  'Team',
#  'Number',
#  'Position',
#  'Age',
#  'Height',
#  'Weight',
#  'College',
#  'Salary']

# %%
df_employee["Team"].unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz'],
#       dtype=object)

# %%
df_employee["Position"].unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %%
Height = np.random.randint(150,180,size=458)
df_employee["Height"]=Height
df_employee.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     170     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     172     235
# 2   John Holland  Boston Celtics      30       SG   27     155     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     157     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     173     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
#missing_data percentage
total  = df_employee.isnull().sum().sort_values(ascending=False)
percentage = (df_employee.isnull().sum()/df_employee.isnull().count()).sort_values(ascending=False)
missing_percentage =pd.concat([total,percentage],axis=1,keys=["TOTAL","PERCENTAGE"])
missing_percentage.head(10)
# Out:
#           TOTAL  PERCENTAGE
# College      84    0.183406
# Salary       11    0.024017
# Name          0    0.000000
# Team          0    0.000000
# Number        0    0.000000
# Position      0    0.000000
# Age           0    0.000000
# Height        0    0.000000
# Weight        0    0.000000

# %%
df_employee["Team"].value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %% [markdown]
# ##**TEAM DISTRIBUTION AND PERCENTAGE SPLITTING RELATIVE TO TOTAL EMPLOYEES**

# %%
plt.figure(figsize=(30,7))
plt.xticks(rotation=90)
sns.countplot(x='Team',data=df_employee,hue= 'Team',palette='mako')
plt.show()

# %%
# Count the number of employees in each team
team_counts = df_employee["Team"].value_counts()

# Calculate the total number of employees
total_employees = len(df_employee)

# Calculate the percentage of employees in each team
percentage = (team_counts / total_employees) * 100

# Create a DataFrame to display results
result = pd.DataFrame({'No of Employees': team_counts, 'Percentage': percentage.round(2)})

# Display the result
print(result)
# Out:
#                         No of Employees  Percentage
# Team
# New Orleans Pelicans                 19        4.15
# Memphis Grizzlies                    18        3.93
# Utah Jazz                            16        3.49
# New York Knicks                      16        3.49
# Milwaukee Bucks                      16        3.49
# Brooklyn Nets                        15        3.28
# Portland Trail Blazers               15        3.28
# Oklahoma City Thunder                15        3.28
# Denver Nuggets                       15        3.28
# Washington Wizards                   15        3.28
# Miami Heat                           15        3.28
# Charlotte Hornets                    15        3.28
# Atlanta Hawks                        15        3.28
# San Antonio Spurs                    15        3.28
# Houston Rockets                      15        3.28
# Boston Celtics                       15        3.28
# Indiana Pacers                       15        3.28
# ...

# %%
df_employee["Position"].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
df_employee[df_employee["Position"]=="PG"]
# Out:
#               Name                    Team  Number Position  Age  Height  \
# 0    Avery Bradley          Boston Celtics       0       PG   25     170
# 8     Terry Rozier          Boston Celtics      12       PG   22     168
# 9     Marcus Smart          Boston Celtics      36       PG   22     171
# 11   Isaiah Thomas          Boston Celtics       4       PG   27     176
# 19    Jarrett Jack           Brooklyn Nets       2       PG   32     155
# ..             ...                     ...     ...      ...  ...     ...
# 440  Brian Roberts  Portland Trail Blazers       2       PG   30     163
# 443     Trey Burke               Utah Jazz       3       PG   23     155
# 445     Dante Exum               Utah Jazz      11       PG   20     172
# 453   Shelvin Mack               Utah Jazz       8       PG   26     174
# 454      Raul Neto               Utah Jazz      25       PG   24     151
#
#      Weight         College     Salary
# 0       180           Texas  7730337.0
# ...

# %%
df_employee[df_employee["Position"]=="SG"]
# Out:
#                  Name                    Team  Number Position  Age  Height  \
# 2        John Holland          Boston Celtics      30       SG   27     155
# 3         R.J. Hunter          Boston Celtics      28       SG   22     157
# 12        Evan Turner          Boston Celtics      11       SG   27     164
# 13        James Young          Boston Celtics      13       SG   20     155
# 15   Bojan Bogdanovic           Brooklyn Nets      44       SG   27     169
# ..                ...                     ...     ...      ...  ...     ...
# 433  Gerald Henderson  Portland Trail Blazers       9       SG   28     178
# 437     C.J. McCollum  Portland Trail Blazers       3       SG   24     163
# 438      Luis Montero  Portland Trail Blazers      44       SG   23     165
# 444        Alec Burks               Utah Jazz      10       SG   24     173
# 449       Rodney Hood               Utah Jazz       5       SG   23     156
#
#      Weight            College     Salary
# ...

# %%
df_employee[df_employee["Position"]=="PF"]
df_employee[df_employee["Position"]=="SF"]
df_employee[df_employee["Position"]=="C"]
# Out:
#                 Name                    Team  Number Position  Age  Height  \
# 7       Kelly Olynyk          Boston Celtics      41        C   25     158
# 10   Jared Sullinger          Boston Celtics       7        C   24     177
# 14      Tyler Zeller          Boston Celtics      44        C   26     174
# 23       Brook Lopez           Brooklyn Nets      11        C   28     173
# 27        Henry Sims           Brooklyn Nets      14        C   26     161
# ..               ...                     ...     ...      ...  ...     ...
# 439    Mason Plumlee  Portland Trail Blazers      24        C   26     153
# 447      Rudy Gobert               Utah Jazz      27        C   23     178
# 455     Tibor Pleiss               Utah Jazz      21        C   26     152
# 456      Jeff Withey               Utah Jazz      24        C   26     172
# 457         Priyanka               Utah Jazz      34        C   25     165
#
#      Weight         College      Salary
# ...

# %%
#grouping employees by position
grp_position = df_employee.groupby("Position")
for position, group in grp_position:
    print(f"position:{position}")
    print(group[["Name","Position"]])
    print("\n")
# Out:
# position:C
#                 Name Position
# 7       Kelly Olynyk        C
# 10   Jared Sullinger        C
# 14      Tyler Zeller        C
# 23       Brook Lopez        C
# 27        Henry Sims        C
# ..               ...      ...
# 439    Mason Plumlee        C
# 447      Rudy Gobert        C
# 455     Tibor Pleiss        C
# 456      Jeff Withey        C
# 457         Priyanka        C
#
# [79 rows x 2 columns]
#
#
# position:PF
#                  Name Position
# 4       Jonas Jerebko       PF
# 5        Amir Johnson       PF
# 6       Jordan Mickey       PF
# 24   Chris McCullough       PF
# 25        Willie Reed       PF
# ..                ...      ...
# 435    Meyers Leonard       PF
# 441       Noah Vonleh       PF
# 442     Trevor Booker       PF
# 446    Derrick Favors       PF
# 452        Trey Lyles       PF
#
# [100 rows x 2 columns]
#
#
# position:PG
#               Name Position
# 0    Avery Bradley       PG
# 8     Terry Rozier       PG
# ...

# %%
positions = df_employee["Position"].unique()
print("unique positions :",positions)
plt.figure(figsize=(7.5,5.5))
plt.title("employee count by position")
sns.countplot(x = "Position",data = df_employee,hue="Position",palette = "mako")
# Out:
# unique positions : ['PG' 'SF' 'SG' 'PF' 'C']
# <Axes: title={'center': 'employee count by position'}, xlabel='Position', ylabel='count'>

# %% [markdown]
# ##**Find from which age group most of the employees belong to**

# %%
df_employee["Age"]
# Out:
# 0      25
# 1      25
# 2      27
# 3      22
# 4      29
#        ..
# 453    26
# 454    24
# 455    26
# 456    26
# 457    25
# Name: Age, Length: 458, dtype: int64

# %%
df_employee["Age"].unique()
# Out:
# array([25, 27, 22, 29, 21, 24, 20, 26, 28, 32, 23, 30, 33, 34, 37, 36, 31,
#        38, 39, 19, 35, 40], dtype=int64)

# %%
df_employee["Age"].nunique()
# Out:
# 22

# %%
df_employee["Age"].value_counts()
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(x = "Age",data = df_employee,hue  ="Age",palette  ="mako")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
df_employee['Age Group'] = df_employee['Age'].apply(lambda age:'20-25' if 20 <= age <= 25 else ('26-30' if 26 <= age <= 30 else ('31-35' if 31 <= age <= 35 else '36 -40')))
df_employee
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     170     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     172     235
# 2     John Holland  Boston Celtics      30       SG   27     155     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     157     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     173     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     174     203
# 454      Raul Neto       Utah Jazz      25       PG   24     151     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     152     256
# 456    Jeff Withey       Utah Jazz      24        C   26     172     231
# 457       Priyanka       Utah Jazz      34        C   25     165     231
#
#                College     Salary Age Group
# 0                Texas  7730337.0     20-25
# ...

# %%
df_employee["Age Group"].value_counts()
# Out:
# Age Group
# 20-25     198
# 26-30     167
# 31-35      68
# 36 -40     25
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(x="Age Group",data = df_employee,palette = "mako",hue = "Age Group")
# Out:
# <Axes: xlabel='Age Group', ylabel='count'>

# %% [markdown]
# **Data story**
#
# *1. Analysis of the counterplot based on the extraction of employee ages reveals that the majority, around 198 individuals, fall within the age range of 20-25 years.*
#
# *2. Conversely, there are fewer individuals, specifically 25 employees, within the age range of 36-40 years.*

# %% [markdown]
# ##**Find out under which team and position, spending in terms of salary is high.**

# %%
df_employee.loc[:,['Team','Position','Salary']]
# Out:
#                Team Position     Salary
# 0    Boston Celtics       PG  7730337.0
# 1    Boston Celtics       SF  6796117.0
# 2    Boston Celtics       SG        NaN
# 3    Boston Celtics       SG  1148640.0
# 4    Boston Celtics       PF  5000000.0
# ..              ...      ...        ...
# 453       Utah Jazz       PG  2433333.0
# 454       Utah Jazz       PG   900000.0
# 455       Utah Jazz        C  2900000.0
# 456       Utah Jazz        C   947276.0
# 457       Utah Jazz        C   947276.0
#
# [458 rows x 3 columns]

# %%
df_employee["Salary"].value_counts()
# Out:
# Salary
# 947276.0      32
# 845059.0      18
# 525093.0      13
# 981348.0       6
# 16407500.0     5
#               ..
# 2100000.0      1
# 1252440.0      1
# 2891760.0      1
# 3272091.0      1
# 900000.0       1
# Name: count, Length: 309, dtype: int64

# %%
df1 = df_employee[["Name","Team","Position","Salary"]]
df1
# Out:
#               Name            Team Position     Salary
# 0    Avery Bradley  Boston Celtics       PG  7730337.0
# 1      Jae Crowder  Boston Celtics       SF  6796117.0
# 2     John Holland  Boston Celtics       SG        NaN
# 3      R.J. Hunter  Boston Celtics       SG  1148640.0
# 4    Jonas Jerebko  Boston Celtics       PF  5000000.0
# ..             ...             ...      ...        ...
# 453   Shelvin Mack       Utah Jazz       PG  2433333.0
# 454      Raul Neto       Utah Jazz       PG   900000.0
# 455   Tibor Pleiss       Utah Jazz        C  2900000.0
# 456    Jeff Withey       Utah Jazz        C   947276.0
# 457       Priyanka       Utah Jazz        C   947276.0
#
# [458 rows x 4 columns]

# %%
total_salary = df1.groupby(["Team","Position"])["Salary"].sum()
max_spending = total_salary.idxmax()
max_spending_salary = total_salary.max()
print(f"The team and position with the highest spending is:\n Team: {max_spending[0]}\n position: {max_spending[1]} \n with a total salary of {max_spending_salary}.")
# Out:
# The team and position with the highest spending is:
#  Team: Los Angeles Lakers
#  position: SF
#  with a total salary of 31866445.0.

# %% [markdown]
# ##**Scatterplot**

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(y = "Salary",x="Team",hue = "Position",data = df_employee)
plt.ylabel("Salary")
plt.xlabel("Team")
plt.title("scatter plot position vs team with salary")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 1. *A scatter plot depicting salary distribution across different positions within each team highlights that the Los Angeles Lakers emerge as the highest spending team.*
#
# 2. *The visualization illustrates that salaries vary across positions within each team, with the Los Angeles Lakers notably exhibiting the highest expenditure compared to other teams.*

# %% [markdown]
# ##**Find if there is any correlation between age and salary , represent it visually**
# ###correlation:
#
# *Values close to +1 indicates strong positive correlation, -1 indicates a strong negative correlation and 0 indicates suggests no linear correlation. Darker colors signify strong correlation, while light colors represents weaker correlations. Positive correlation variable move in same directions. As one increases, the other also increases. Negative correlation variable move in opposite directions. An increase in one variable is associated with a decrease in the other.*
#
# ###heat Maps
#
# *Heat Maps is a type of plot which is necessary when we need to find the dependent variables. One of the best way to find the relationship between the features can be done using heat mapsIn*

# %%
df2 = df_employee[["Age","Salary"]]
df2
# Out:
#      Age     Salary
# 0     25  7730337.0
# 1     25  6796117.0
# 2     27        NaN
# 3     22  1148640.0
# 4     29  5000000.0
# ..   ...        ...
# 453   26  2433333.0
# 454   24   900000.0
# 455   26  2900000.0
# 456   26   947276.0
# 457   25   947276.0
#
# [458 rows x 2 columns]

# %%
corr = df2.corr()
corr
# Out:
#              Age    Salary
# Age     1.000000  0.214009
# Salary  0.214009  1.000000

# %%
sns.heatmap(corr,annot=True,cmap="mako")
plt.title("correlation matrix between age and salary of employees")
plt.show()

# %% [markdown]
# ##**Data Story:**
#
# 1. *Age vs. Age (1.0000): The value of 1.0000 along the diagonal signifies a perfect positive correlation, as expected.*
#
# 2. *Age vs. Salary (0.21117): The correlation coefficient of 0.21117 indicates a positive but weak relationship between age and salary. With increasing age, there's a slight tendency for salaries to rise, but the correlation is not very strong.*
#
# 3. *Salary vs. Age (0.21117): This symmetric measure mirrors the correlation between "Age" and "Salary," reaffirming the weak positive relationship between the two variables.*
#
# *In essence, the correlation matrix reveals a positive yet relatively weak association between age and salary in the employee dataset. As employees' ages increase, there's a tendency for their salaries to slightly rise.8

# %% [markdown]
# In summary, the exploratory data analysis (EDA) conducted on the employee dataset of ABC COMPANY has provided valuable insights into the dataset's characteristics. By examining correlations between variables, detecting outliers, and understanding the distribution of key features through statistical summaries and visualizations, we gained a comprehensive understanding of the dataset's quantitative and qualitative aspects. Various plots, including pair plots, box plots, and histograms, were employed to meticulously analyze patterns, trends, and potential areas for further investigation. This EDA approach facilitated the visualization and analysis of complex datasets using Python libraries such as Matplotlib, Seaborn, and Pandas. The findings offer a robust comprehension of the dataset and establish a foundation for subsequent in-depth analyses and modeling endeavors.
